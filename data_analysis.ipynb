# %%
# %run webscrapping_creating_df_Dong.ipynb
# %run api_and_webscraping_sam.ipynb

# %%
award_df = df
award_df
# Out:
#                     Title  Runtime                        Genre  \
# 0         Planet Earth II  298 min                  Documentary
# 1            Planet Earth  538 min                  Documentary
# 2        Band of Brothers  594 min  Action, Drama, History, War
# 3            Breaking Bad   49 min       Crime, Drama, Thriller
# 4               Chernobyl  330 min     Drama, History, Thriller
# ..                    ...      ...                          ...
# 245              Futurama   22 min    Animation, Comedy, Sci-Fi
# 246            Succession   60 min                        Drama
# 247  American Crime Story   42 min      Biography, Crime, Drama
# 248           Delhi Crime   50 min                 Crime, Drama
# 249   My Brilliant Friend   50 min       Drama, Family, Romance
#
#                                                 Awards imdbRating  imdbVotes  \
# 0    Won 2 Primetime Emmys. Another 11 wins & 21 no...        9.5     86,448
# 1    Won 4 Primetime Emmys. Another 11 wins & 15 no...        9.4    158,749
# 2    Won 1 Golden Globe. Another 33 wins & 25 nomin...        9.5    347,816
# 3    Won 2 Golden Globes. Another 151 wins & 234 no...        9.5  1,325,388
# 4    Won 2 Golden Globes. Another 50 wins & 40 nomi...        9.4    429,873
# ..                                                 ...        ...        ...
# 245  Won 6 Primetime Emmys. Another 24 wins & 56 no...        8.4    205,001
# 246  Won 2 Golden Globes. Another 19 wins & 33 nomi...        8.5     24,844
# 247  Won 4 Golden Globes. Another 93 wins & 117 nom...        8.4     73,442
# 248                                            2 wins.        8.5      7,643
# 249                            2 wins & 6 nominations.        8.5      6,775
#
#         imdbID    Type totalSeasons
# 0    tt5491994  series            1
# 1    tt0795176  series            1
# 2    tt0185906  series            1
# 3    tt0903747  series            5
# 4    tt7366338  series            1
# ..         ...     ...          ...
# 245  tt0149460  series            7
# 246  tt7660850  series            3
# 247  tt2788432  series            4
# 248  tt9398466  series            1
# 249  tt7278862  series            2
#
# [250 rows x 9 columns]

# %%
award_df.rename(columns={'imdbID':'imdb_id'}, inplace=True)

# %%
net_show
# Out:
#        imdb_id                 title         type  \
# 0    tt5491994       Planet Earth II  Documentary
# 1    tt0795176          Planet Earth  Documentary
# 2    tt0185906      Band of Brothers     Scripted
# 3    tt0903747          Breaking Bad     Scripted
# 4    tt7366338             Chernobyl     Scripted
# ..         ...                   ...          ...
# 218  tt0149460              Futurama    Animation
# 219  tt7660850            Succession     Scripted
# 220  tt2788432  American Crime Story     Scripted
# 221  tt9398466           Delhi Crime     Scripted
# 222  tt7278862   My Brilliant Friend     Scripted
#
#                                     genre  runtime  rating webChannel  \
# 0                                [Nature]     60.0     9.7      False
# 1                                [Nature]     60.0     9.4      False
# 2                    [Drama, Action, War]     60.0     9.4      False
# 3                [Drama, Crime, Thriller]     60.0     9.3    Netflix
# 4                        [Drama, History]     60.0     9.1      False
# ..                                    ...      ...     ...        ...
# 218  [Comedy, Adventure, Science-Fiction]     30.0     9.0      False
# 219                       [Drama, Family]     60.0     6.8      False
# 220                        [Drama, Crime]     60.0     7.3      False
# 221                        [Drama, Crime]     50.0     NaN    Netflix
# 222                               [Drama]     60.0     7.4      False
#
#             network
# 0           BBC One
# 1           BBC One
# 2               HBO
# 3               AMC
# 4               HBO
# ..              ...
# 218  Comedy Central
# 219             HBO
# 220              FX
# 221           False
# 222           Rai 1
#
# [223 rows x 8 columns]

# %%
the_df = pd.merge(award_df, net_show, on='imdb_id')

# %%
the_df
# Out:
#                     Title  Runtime                        Genre  \
# 0         Planet Earth II  298 min                  Documentary
# 1            Planet Earth  538 min                  Documentary
# 2        Band of Brothers  594 min  Action, Drama, History, War
# 3            Breaking Bad   49 min       Crime, Drama, Thriller
# 4               Chernobyl  330 min     Drama, History, Thriller
# ..                    ...      ...                          ...
# 218              Futurama   22 min    Animation, Comedy, Sci-Fi
# 219            Succession   60 min                        Drama
# 220  American Crime Story   42 min      Biography, Crime, Drama
# 221           Delhi Crime   50 min                 Crime, Drama
# 222   My Brilliant Friend   50 min       Drama, Family, Romance
#
#                                                 Awards imdbRating  imdbVotes  \
# 0    Won 2 Primetime Emmys. Another 11 wins & 21 no...        9.5     86,448
# 1    Won 4 Primetime Emmys. Another 11 wins & 15 no...        9.4    158,749
# 2    Won 1 Golden Globe. Another 33 wins & 25 nomin...        9.5    347,816
# 3    Won 2 Golden Globes. Another 151 wins & 234 no...        9.5  1,325,388
# 4    Won 2 Golden Globes. Another 50 wins & 40 nomi...        9.4    429,873
# ..                                                 ...        ...        ...
# 218  Won 6 Primetime Emmys. Another 24 wins & 56 no...        8.4    205,001
# 219  Won 2 Golden Globes. Another 19 wins & 33 nomi...        8.5     24,844
# 220  Won 4 Golden Globes. Another 93 wins & 117 nom...        8.4     73,442
# 221                                            2 wins.        8.5      7,643
# 222                            2 wins & 6 nominations.        8.5      6,775
#
#        imdb_id    Type totalSeasons                 title         type  \
# 0    tt5491994  series            1       Planet Earth II  Documentary
# 1    tt0795176  series            1          Planet Earth  Documentary
# 2    tt0185906  series            1      Band of Brothers     Scripted
# 3    tt0903747  series            5          Breaking Bad     Scripted
# 4    tt7366338  series            1             Chernobyl     Scripted
# ..         ...     ...          ...                   ...          ...
# 218  tt0149460  series            7              Futurama    Animation
# 219  tt7660850  series            3            Succession     Scripted
# 220  tt2788432  series            4  American Crime Story     Scripted
# 221  tt9398466  series            1           Delhi Crime     Scripted
# 222  tt7278862  series            2   My Brilliant Friend     Scripted
#
#                                     genre  runtime  rating webChannel  \
# 0                                [Nature]     60.0     9.7      False
# 1                                [Nature]     60.0     9.4      False
# 2                    [Drama, Action, War]     60.0     9.4      False
# 3                [Drama, Crime, Thriller]     60.0     9.3    Netflix
# 4                        [Drama, History]     60.0     9.1      False
# ..                                    ...      ...     ...        ...
# 218  [Comedy, Adventure, Science-Fiction]     30.0     9.0      False
# 219                       [Drama, Family]     60.0     6.8      False
# 220                        [Drama, Crime]     60.0     7.3      False
# 221                        [Drama, Crime]     50.0     NaN    Netflix
# 222                               [Drama]     60.0     7.4      False
#
#             network
# 0           BBC One
# 1           BBC One
# 2               HBO
# 3               AMC
# 4               HBO
# ..              ...
# 218  Comedy Central
# 219             HBO
# 220              FX
# 221           False
# 222           Rai 1
#
# [223 rows x 16 columns]

# %%
the_df.to_csv('show_data.csv')

# %%
pd.read_csv('show_data.csv',index_col=0)
# Out:
#                     Title  Runtime                        Genre  \
# 0         Planet Earth II  298 min                  Documentary
# 1            Planet Earth  538 min                  Documentary
# 2        Band of Brothers  594 min  Action, Drama, History, War
# 3            Breaking Bad   49 min       Crime, Drama, Thriller
# 4               Chernobyl  330 min     Drama, History, Thriller
# ..                    ...      ...                          ...
# 218              Futurama   22 min    Animation, Comedy, Sci-Fi
# 219            Succession   60 min                        Drama
# 220  American Crime Story   42 min      Biography, Crime, Drama
# 221           Delhi Crime   50 min                 Crime, Drama
# 222   My Brilliant Friend   50 min       Drama, Family, Romance
#
#                                                 Awards  imdbRating  imdbVotes  \
# 0    Won 2 Primetime Emmys. Another 11 wins & 21 no...         9.5     86,448
# 1    Won 4 Primetime Emmys. Another 11 wins & 15 no...         9.4    158,749
# 2    Won 1 Golden Globe. Another 33 wins & 25 nomin...         9.5    347,816
# 3    Won 2 Golden Globes. Another 151 wins & 234 no...         9.5  1,325,388
# 4    Won 2 Golden Globes. Another 50 wins & 40 nomi...         9.4    429,873
# ..                                                 ...         ...        ...
# 218  Won 6 Primetime Emmys. Another 24 wins & 56 no...         8.4    205,001
# 219  Won 2 Golden Globes. Another 19 wins & 33 nomi...         8.5     24,844
# 220  Won 4 Golden Globes. Another 93 wins & 117 nom...         8.4     73,442
# 221                                            2 wins.         8.5      7,643
# 222                            2 wins & 6 nominations.         8.5      6,775
#
#        imdb_id    Type  totalSeasons                 title         type  \
# 0    tt5491994  series           1.0       Planet Earth II  Documentary
# 1    tt0795176  series           1.0          Planet Earth  Documentary
# 2    tt0185906  series           1.0      Band of Brothers     Scripted
# 3    tt0903747  series           5.0          Breaking Bad     Scripted
# 4    tt7366338  series           1.0             Chernobyl     Scripted
# ..         ...     ...           ...                   ...          ...
# 218  tt0149460  series           7.0              Futurama    Animation
# 219  tt7660850  series           3.0            Succession     Scripted
# 220  tt2788432  series           4.0  American Crime Story     Scripted
# 221  tt9398466  series           1.0           Delhi Crime     Scripted
# 222  tt7278862  series           2.0   My Brilliant Friend     Scripted
#
#                                           genre  runtime  rating webChannel  \
# 0                                    ['Nature']     60.0     9.7      False
# 1                                    ['Nature']     60.0     9.4      False
# 2                    ['Drama', 'Action', 'War']     60.0     9.4      False
# 3                ['Drama', 'Crime', 'Thriller']     60.0     9.3    Netflix
# 4                          ['Drama', 'History']     60.0     9.1      False
# ..                                          ...      ...     ...        ...
# 218  ['Comedy', 'Adventure', 'Science-Fiction']     30.0     9.0      False
# 219                         ['Drama', 'Family']     60.0     6.8      False
# 220                          ['Drama', 'Crime']     60.0     7.3      False
# 221                          ['Drama', 'Crime']     50.0     NaN    Netflix
# 222                                   ['Drama']     60.0     7.4      False
#
#             network
# 0           BBC One
# 1           BBC One
# 2               HBO
# 3               AMC
# 4               HBO
# ..              ...
# 218  Comedy Central
# 219             HBO
# 220              FX
# 221           False
# 222           Rai 1
#
# [223 rows x 16 columns]
